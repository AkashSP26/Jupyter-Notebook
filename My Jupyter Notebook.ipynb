# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __AKASH__
# I want to be Data Scientist

# %% [markdown]
# *I am interested in data science because I would like to contribute to agriculture sector*

# %% [markdown]
# ### Print as " This is Jupyter Notebook "

# %%
print("This is Jupyter Notebook")
# Out:
# This is Jupyter Notebook

# %% [markdown]
# ~~Col_1~~ | Col_2| Col_3
# ---      | :---   :| :---
# *This* | `is` | **Cool!!**
# 1 | 2 | 3
